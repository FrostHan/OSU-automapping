# %%
import tensorflow as tf
import scipy.io as sio
import matplotlib.pyplot as plt
import os
import numpy as np
import shutil
from datetime import datetime
now = datetime.now()

shutil.rmtree('D:/MATLAB/OSU/OSU-automapping/Train/log/', ignore_errors=True)

sess = tf.InteractiveSession()

# %% [markdown]
# ## TensorBoard-Piliang-logfre-frePooling-deep
# ### Two groups of output
#
# - One classification output(1x2) for recognizing if there is a object, minimizing cross entropy using softmax
# - One fitting network(1x4) for deciding if a object should be a circle/sliderHead/sliderEnd, minimizing MSE using sigmoid

# %%
learning_rate = 1e-5
channels_input = 32
channels_output = 32
gamma = 0.33 # relative strength of 4-D term

fc_input_dim = int(128*128*channels_output/2**4/2/2/2/2)
fc_hidden1_dim = 256
fc_hidden2_dim = 256

fc_input_dim
# Out:
# 2048

# %%
def conv2d(x, W, dy=1 ,dx=1):
    return tf.nn.conv2d(x, W, strides=[1, dx, dy, 1], padding='SAME')

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def max_pool_axb(x,a,b):
    return tf.nn.max_pool(x, ksize=[1, a, b, 1], strides=[1, a, b, 1], padding='SAME')

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def variable_summaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
#     with tf.name_scope('summaries'):
#         mean = tf.reduce_mean(var)
#         tf.summary.scalar('mean', mean)
#         with tf.name_scope('stddev'):
#             stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
#         tf.summary.scalar('stddev', stddev)
#         tf.summary.scalar('max', tf.reduce_max(var))
#         tf.summary.scalar('min', tf.reduce_min(var))
#         tf.summary.histogram('histogram', var)

def conv_layer(input_tensor, filter_height, filter_width, channels_input, channels_output, layer_name, act=tf.nn.relu):
  # Adding a name scope ensures logical grouping of the layers in the graph.
    with tf.name_scope(layer_name):
    # This Variable will hold the state of the weights for the layer
        with tf.name_scope('weights'):
            weights = weight_variable([filter_height, filter_width, channels_input, channels_output])
            variable_summaries(weights)
        with tf.name_scope('biases'):
            biases = bias_variable([channels_output])
            variable_summaries(biases)
        with tf.name_scope('Wx_plus_b'):
            preactivate = conv2d(input_tensor, weights,2,1) + biases
#             tf.summary.histogram('pre_activations', preactivate)
        activations = act(preactivate, name='activation')
#         tf.summary.histogram('activations', activations)
        return activations

def fc_layer(input_tensor, input_dim, output_dim, layer_name, act=tf.nn.relu):
    # Adding a name scope ensures logical grouping of the layers in the graph.
    with tf.name_scope(layer_name):
    # This Variable will hold the state of the weights for the layer
        with tf.name_scope('weights'):
            weights = weight_variable([input_dim, output_dim])
            variable_summaries(weights)
        with tf.name_scope('biases'):
            biases = bias_variable([output_dim])
            variable_summaries(biases)
        with tf.name_scope('Wx_plus_b'):
            preactivate = tf.matmul(input_tensor, weights) + biases
#             tf.summary.histogram('pre_activations', preactivate)
        activations = act(preactivate, name='activation')
#         tf.summary.histogram('activations', activations)
        return activations
    
def output_layer(input_tensor, input_dim, output_dim, layer_name, act=tf.nn.softmax):
    # Adding a name scope ensures logical grouping of the layers in the graph.
    with tf.name_scope(layer_name):
    # This Variable will hold the state of the weights for the layer
        with tf.name_scope('weights'):
            weights = weight_variable([input_dim, output_dim])
            variable_summaries(weights)
        with tf.name_scope('biases'):
            biases = bias_variable([output_dim])
            variable_summaries(biases)
        with tf.name_scope('Wx_plus_b'):
            preactivate = tf.matmul(input_tensor, weights) + biases
#             tf.summary.histogram('pre_activations', preactivate)
        activations = act(preactivate, name='activation')
#         tf.summary.histogram('activations', activations)
        return activations 

def batch_norm_layer(x, train_phase, scope_bn):
    with tf.variable_scope(scope_bn):
        beta = tf.Variable(tf.constant(0.0, shape=[x.shape[-1]]), name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[x.shape[-1]]), name='gamma', trainable=True)
        axises = np.arange(len(x.shape) - 1)
        batch_mean, batch_var = tf.nn.moments(x, axises, name='moments')
        ema = tf.train.ExponentialMovingAverage(decay=0.5)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(train_phase, mean_var_with_update, lambda: (ema.average(batch_mean), ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed    
    
########################   Structure   ##############################

with tf.name_scope('spectrogram_input'):
    x = tf.placeholder("float", shape=[None, 128*128] , name='flat_input')
with tf.name_scope('target'):
    y_2 = tf.placeholder("float", shape=[None, 2], name='target_2')
    y_4 = tf.placeholder("float", shape=[None, 4], name='target_4')
with tf.name_scope('input'):
    x_image = tf.reshape(x, [-1,128,128,1] , name='2D_input')

h_conv1 = conv_layer(x_image, 16, 4,            1,      channels_output, 'conv_layer_1' , act=tf.nn.relu)
h_conv1_pl = max_pool_axb(h_conv1, 2, 1)

h_conv2 = conv_layer(h_conv1_pl, 4, 16, channels_input, channels_output, 'conv_layer_2' , act=tf.nn.relu)
h_conv2_pl = max_pool_axb(h_conv2, 2, 1)

h_conv3 = conv_layer(h_conv2_pl, 16, 4, channels_input, channels_output, 'conv_layer_3' , act=tf.nn.relu)
h_conv3_pl = max_pool_axb(h_conv3, 2, 1)

h_conv4 = conv_layer(h_conv3_pl, 4, 16, channels_input, channels_output, 'conv_layer_4' , act=tf.nn.relu)
h_conv4_pl = max_pool_axb(h_conv4, 2, 1)



with tf.name_scope('reshape'):
    h_before_fc = tf.reshape(h_conv4_pl, [-1,fc_input_dim])

h_fc1 = fc_layer(h_before_fc, fc_input_dim, fc_hidden1_dim, 'hidden_layer_1' , act=tf.nn.relu)
h_fc2 = fc_layer(h_fc1, fc_hidden1_dim, fc_hidden2_dim, 'hidden_layer_2' , act=tf.nn.relu)


with tf.name_scope('dropout'):
    keep_prob = tf.placeholder("float")
    h_fc_drop = tf.nn.dropout(h_fc2, keep_prob)

with tf.name_scope('output'):
    y2 = output_layer(h_fc_drop, fc_hidden2_dim, 2, 'output_layer_2D' , act=tf.nn.softmax)
    y4 = output_layer(h_fc_drop, fc_hidden2_dim, 4, 'output_layer_4D' , act=tf.nn.sigmoid)
    # tf.summary.histogram('y',y)


with tf.name_scope('loss'):
    with tf.name_scope('cross_entropy'):
        diff2 = - y_2 * tf.log(tf.clip_by_value(y2, 1e-20, 1.0))
    with tf.name_scope('mean_squared_error'):
        diff4 = tf.losses.mean_squared_error(y_4, y4)
    
    cross_entropy = tf.reduce_mean(diff2)
    mse = tf.reduce_mean(diff4) 
    loss = cross_entropy + gamma * mse

# tf.summary.histogram('cross_entropy_individual',diff)
tf.summary.scalar('cross_entropy', cross_entropy)
tf.summary.scalar('mse', mse)
tf.summary.scalar('loss', loss)

with tf.name_scope('train'):
    train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)

with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction_2'):
        correct_prediction_2 = tf.equal(tf.argmax(y2, 1), tf.argmax(y_2, 1))
    with tf.name_scope('accuracy_2'):
        accuracy_2 = tf.reduce_mean(tf.cast(correct_prediction_2, tf.float32))
    tf.summary.scalar('accuracy_2', accuracy_2)
    
    with tf.name_scope('correct_prediction_4'):
        correct_prediction_4 = tf.equal(tf.argmax(y4, 1), tf.argmax(y_4, 1))
    with tf.name_scope('accuracy_4'):
        accuracy_4 = tf.reduce_mean(tf.cast(correct_prediction_4, tf.float32))
    tf.summary.scalar('accuracy_4', accuracy_4)

# %%
############################## Initialization & Read Data  #######################

summaries_dir = 'D:/MATLAB/OSU/OSU-automapping/Train/log/train'+now.strftime("%Y%m%d-%H%M%S") + "/"

merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(summaries_dir + '/train',sess.graph)
test_writer = tf.summary.FileWriter(summaries_dir + '/test')
sess.run(tf.global_variables_initializer())

saver = tf.train.Saver()


# Test Data

testData = sio.loadmat('D:/OSU/SongMat/Test/532522 SakiZ - osu!memories.mat')
inputTest = testData['input'].reshape(-1,128*128)
targetTest = testData['target'].reshape(-1,4)

targetTest2 = np.zeros([targetTest.shape[0],2])
targetTest2[:,0] = targetTest[:,0]+targetTest[:,1]+targetTest[:,2]
targetTest2[:,1] = targetTest[:,3]

targetTest4 = np.zeros([targetTest.shape[0],4])
targetTest4[:,0] = targetTest[:,0] + 0.5*targetTest[:,1] + 0.5*targetTest[:,2]
targetTest4[:,1] = 0.5*targetTest[:,0] + targetTest[:,1] + 0.5*targetTest[:,2]
targetTest4[:,2] = 0.5*targetTest[:,0] + 0.5*targetTest[:,1] + targetTest[:,2]
targetTest4[:,3] = targetTest[:,3]

    
NTest=targetTest2.shape[0]

# %%
############################## Training  #######################

# batch_size = 20
step_size = 100
dataList=os.listdir('D:/OSU/SongMat/Train/')
# acc=np.zeros([1000,1])

n = 1
total_steps = 0
while n < np.size(dataList)-18:
    n = n + 3
    inputOsu=np.empty([0,128*128])
    targetOsu=np.empty([0,4])
    for k in range(n,n+15):
        
        data=sio.loadmat('D:/OSU/SongMat/Train/'+dataList[k])
        inputOsu=np.append(inputOsu,data['input1'].reshape(-1,128*128),axis=0)
        targetOsu=np.append(targetOsu,data['target1'].reshape(-1,4),axis=0)
               
    targetOsu2 = np.zeros([targetOsu.shape[0],2]);
    targetOsu2[:,0] = targetOsu[:,0] + targetOsu[:,1] + targetOsu[:,2]
    targetOsu2[:,1] = targetOsu[:,3]
    
    targetOsu4 = np.zeros([targetOsu.shape[0],4])
    targetOsu4[:,0] = targetOsu[:,0] + 0.5*targetOsu[:,1] + 0.5*targetOsu[:,2]
    targetOsu4[:,1] = 0.5*targetOsu[:,0] + targetOsu[:,1] + 0.5*targetOsu[:,2]
    targetOsu4[:,2] = 0.5*targetOsu[:,0] + 0.5*targetOsu[:,1] + targetOsu[:,2]
    targetOsu4[:,3] = targetOsu[:,3]
    
    N=inputOsu.shape[0]
    print(N)
    
    #shuffle the order
    order = np.arange(N-step_size)
    np.random.shuffle(order)
    orderAcc = np.arange(NTest)
    np.random.shuffle(orderAcc)
    
    for i in range(N-step_size):
        if i%step_size == 0:
            summary, _  = sess.run([merged, train_step], feed_dict={x: inputOsu[order[i:i+step_size],:], y_2: targetOsu2[order[i:i+step_size],:], y_4: targetOsu4[order[i:i+step_size],:], keep_prob: 0.5})
            test_writer.add_summary(summary, i + total_steps)
#         else:
#             summary = sess.run(merged, feed_dict={x: inputOsu[order[i:i+step_size],:], y_2: targetOsu2[order[i:i+step_size],:], y_4: targetOsu4[order[i:i+step_size],:], keep_prob: 0.5})
#             train_writer.add_summary(summary, i + total_steps)
        if i%1000 == 0:
            accMemory_2 = accuracy_2.eval(feed_dict={x: inputTest[orderAcc[0:300],:], y_2: targetTest2[orderAcc[0:300],:],  y_4: targetTest4[orderAcc[0:300],:], keep_prob: 1.0}) 
            accMemory_4 = accuracy_4.eval(feed_dict={x: inputTest[orderAcc[0:300],:], y_2: targetTest2[orderAcc[0:300],:],  y_4: targetTest4[orderAcc[0:300],:], keep_prob: 1.0}) 
            print("step %5.5d, memory accuracy (2D) %5.3g, memory accuracy (4D) %5.3g" %(i, accMemory_2, accMemory_4))
#             print(y.eval(feed_dict={x: inputTest[orderAcc[1122:1130],:], keep_prob: 1.0}))
            
    total_steps += i
# Out:
# 17803
# step 00000, memory accuracy (2D) 0.507, memory accuracy (4D)   0.1
# step 01000, memory accuracy (2D) 0.507, memory accuracy (4D)   0.1
# step 02000, memory accuracy (2D) 0.507, memory accuracy (4D)   0.1
# step 03000, memory accuracy (2D) 0.507, memory accuracy (4D)   0.1
# step 04000, memory accuracy (2D) 0.603, memory accuracy (4D)   0.1
# step 05000, memory accuracy (2D) 0.507, memory accuracy (4D)   0.1
# step 06000, memory accuracy (2D) 0.493, memory accuracy (4D)   0.1
# step 07000, memory accuracy (2D) 0.497, memory accuracy (4D)   0.1
# step 08000, memory accuracy (2D)  0.52, memory accuracy (4D)   0.1
# step 09000, memory accuracy (2D) 0.603, memory accuracy (4D)   0.1
# step 10000, memory accuracy (2D) 0.597, memory accuracy (4D)   0.1
# step 11000, memory accuracy (2D) 0.533, memory accuracy (4D)   0.1
# step 12000, memory accuracy (2D) 0.527, memory accuracy (4D)   0.1
# step 13000, memory accuracy (2D) 0.523, memory accuracy (4D)   0.1
# step 14000, memory accuracy (2D)  0.59, memory accuracy (4D)   0.1
# step 15000, memory accuracy (2D) 0.617, memory accuracy (4D)   0.1
# step 16000, memory accuracy (2D)  0.62, memory accuracy (4D)   0.1
# step 17000, memory accuracy (2D)  0.57, memory accuracy (4D)   0.1
# 17923
# step 00000, memory accuracy (2D) 0.677, memory accuracy (4D)  0.14
# step 01000, memory accuracy (2D) 0.707, memory accuracy (4D)  0.14
# step 02000, memory accuracy (2D) 0.733, memory accuracy (4D)  0.14
# step 03000, memory accuracy (2D)  0.72, memory accuracy (4D)  0.14
# step 04000, memory accuracy (2D)  0.72, memory accuracy (4D)  0.14
# step 05000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.14
# step 06000, memory accuracy (2D) 0.757, memory accuracy (4D)  0.14
# step 07000, memory accuracy (2D) 0.777, memory accuracy (4D)  0.14
# step 08000, memory accuracy (2D)  0.77, memory accuracy (4D)  0.14
# step 09000, memory accuracy (2D)  0.77, memory accuracy (4D)  0.14
# step 10000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.14
# step 11000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.14
# step 12000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.143
# step 13000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.143
# step 14000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.143
# step 15000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.143
# step 16000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.143
# step 17000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.143
# 17316
# step 00000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.107
# step 01000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.107
# step 02000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.103
# step 03000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.107
# step 04000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.107
# step 05000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.107
# step 06000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.107
# step 07000, memory accuracy (2D) 0.757, memory accuracy (4D) 0.107
# step 08000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.103
# step 09000, memory accuracy (2D) 0.757, memory accuracy (4D) 0.103
# step 10000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.103
# step 11000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.103
# step 12000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.103
# step 13000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.103
# step 14000, memory accuracy (2D)  0.73, memory accuracy (4D)   0.1
# step 15000, memory accuracy (2D)  0.72, memory accuracy (4D)   0.1
# step 16000, memory accuracy (2D) 0.713, memory accuracy (4D) 0.103
# step 17000, memory accuracy (2D) 0.703, memory accuracy (4D) 0.103
# 14253
# step 00000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.103
# step 01000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.107
# step 02000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.0933
# step 03000, memory accuracy (2D) 0.713, memory accuracy (4D) 0.0967
# step 04000, memory accuracy (2D) 0.747, memory accuracy (4D)   0.1
# step 05000, memory accuracy (2D)  0.76, memory accuracy (4D)   0.1
# step 06000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.103
# step 07000, memory accuracy (2D)  0.72, memory accuracy (4D)   0.1
# step 08000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.0967
# step 09000, memory accuracy (2D) 0.737, memory accuracy (4D)   0.1
# step 10000, memory accuracy (2D) 0.733, memory accuracy (4D)  0.11
# step 11000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.117
# step 12000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.127
# step 13000, memory accuracy (2D)  0.73, memory accuracy (4D)  0.13
# step 14000, memory accuracy (2D)  0.74, memory accuracy (4D)  0.13
# 17204
# step 00000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.18
# step 01000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.19
# step 02000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.193
# step 03000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.193
# step 04000, memory accuracy (2D) 0.733, memory accuracy (4D)   0.2
# step 05000, memory accuracy (2D) 0.723, memory accuracy (4D)   0.2
# step 06000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.203
# step 07000, memory accuracy (2D) 0.733, memory accuracy (4D)  0.19
# step 08000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.203
# step 09000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.203
# step 10000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.217
# step 11000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.237
# step 12000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.243
# step 13000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.247
# step 14000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.247
# step 15000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.257
# step 16000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.253
# step 17000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.267
# 14950
# step 00000, memory accuracy (2D)  0.71, memory accuracy (4D)  0.24
# step 01000, memory accuracy (2D) 0.707, memory accuracy (4D) 0.243
# step 02000, memory accuracy (2D) 0.707, memory accuracy (4D)  0.24
# step 03000, memory accuracy (2D) 0.707, memory accuracy (4D) 0.247
# step 04000, memory accuracy (2D) 0.713, memory accuracy (4D) 0.247
# step 05000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.253
# step 06000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.233
# step 07000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.237
# step 08000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.243
# step 09000, memory accuracy (2D) 0.737, memory accuracy (4D)  0.24
# step 10000, memory accuracy (2D)  0.72, memory accuracy (4D)  0.24
# step 11000, memory accuracy (2D)  0.72, memory accuracy (4D)  0.24
# step 12000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.233
# step 13000, memory accuracy (2D) 0.723, memory accuracy (4D)  0.23
# step 14000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.243
# 15829
# step 00000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.257
# step 01000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.257
# step 02000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.253
# step 03000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.263
# step 04000, memory accuracy (2D) 0.763, memory accuracy (4D)  0.27
# step 05000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.287
# step 06000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.29
# step 07000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.29
# step 08000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.293
# step 09000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.31
# step 10000, memory accuracy (2D) 0.813, memory accuracy (4D)   0.3
# step 11000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.307
# step 12000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.31
# step 13000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.293
# step 14000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.303
# step 15000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.323
# 17424
# step 00000, memory accuracy (2D) 0.703, memory accuracy (4D) 0.363
# step 01000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.367
# step 02000, memory accuracy (2D) 0.733, memory accuracy (4D)  0.37
# step 03000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.353
# step 04000, memory accuracy (2D) 0.717, memory accuracy (4D) 0.347
# step 05000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.357
# step 06000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.357
# step 07000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.353
# step 08000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.357
# step 09000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.373
# step 10000, memory accuracy (2D) 0.727, memory accuracy (4D)  0.37
# step 11000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.383
# step 12000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.383
# step 13000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.367
# step 14000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.387
# step 15000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.383
# step 16000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.407
# step 17000, memory accuracy (2D)  0.72, memory accuracy (4D)  0.41
# 21556
# step 00000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.407
# step 01000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.42
# step 02000, memory accuracy (2D) 0.773, memory accuracy (4D)  0.42
# step 03000, memory accuracy (2D) 0.763, memory accuracy (4D) 0.413
# step 04000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.423
# step 05000, memory accuracy (2D) 0.757, memory accuracy (4D) 0.423
# step 06000, memory accuracy (2D) 0.763, memory accuracy (4D)  0.43
# step 07000, memory accuracy (2D) 0.763, memory accuracy (4D) 0.437
# step 08000, memory accuracy (2D) 0.767, memory accuracy (4D)  0.45
# step 09000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.447
# step 10000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.443
# step 11000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.44
# step 12000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.453
# step 13000, memory accuracy (2D)  0.77, memory accuracy (4D)  0.44
# step 14000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.437
# step 15000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.443
# step 16000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.443
# step 17000, memory accuracy (2D)  0.77, memory accuracy (4D)  0.45
# step 18000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.457
# step 19000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.463
# step 20000, memory accuracy (2D)  0.78, memory accuracy (4D)  0.46
# step 21000, memory accuracy (2D) 0.777, memory accuracy (4D)  0.47
# 22131
# step 00000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.447
# step 01000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.457
# step 02000, memory accuracy (2D)  0.72, memory accuracy (4D)  0.46
# step 03000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.473
# step 04000, memory accuracy (2D) 0.733, memory accuracy (4D)  0.48
# step 05000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.483
# step 06000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.48
# step 07000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.493
# step 08000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.493
# step 09000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.497
# step 10000, memory accuracy (2D)  0.74, memory accuracy (4D)   0.5
# step 11000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.517
# step 12000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.507
# step 13000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.513
# step 14000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.517
# step 15000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.507
# step 16000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.497
# step 17000, memory accuracy (2D) 0.753, memory accuracy (4D)   0.5
# step 18000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.497
# step 19000, memory accuracy (2D)  0.75, memory accuracy (4D)   0.5
# step 20000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.473
# step 21000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.487
# step 22000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.493
# 25692
# step 00000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.513
# step 01000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.527
# step 02000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.527
# step 03000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.527
# step 04000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.517
# step 05000, memory accuracy (2D) 0.717, memory accuracy (4D)  0.53
# step 06000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.547
# step 07000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.553
# step 08000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.557
# step 09000, memory accuracy (2D)  0.75, memory accuracy (4D)  0.56
# step 10000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.553
# step 11000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.563
# step 12000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.567
# step 13000, memory accuracy (2D) 0.757, memory accuracy (4D) 0.567
# step 14000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.563
# step 15000, memory accuracy (2D) 0.767, memory accuracy (4D) 0.563
# step 16000, memory accuracy (2D) 0.743, memory accuracy (4D)  0.56
# step 17000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.553
# step 18000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.543
# step 19000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.557
# step 20000, memory accuracy (2D) 0.753, memory accuracy (4D)  0.57
# step 21000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.557
# step 22000, memory accuracy (2D) 0.733, memory accuracy (4D) 0.567
# step 23000, memory accuracy (2D) 0.737, memory accuracy (4D)  0.58
# step 24000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.587
# step 25000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.593
# 26258
# step 00000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.517
# step 01000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.513
# step 02000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.517
# step 03000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.513
# step 04000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.517
# step 05000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.517
# step 06000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.523
# step 07000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.527
# step 08000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.513
# step 09000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.503
# step 10000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.497
# step 11000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.493
# step 12000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.503
# step 13000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.493
# step 14000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.513
# step 15000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.527
# step 16000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.523
# step 17000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.533
# step 18000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.523
# step 19000, memory accuracy (2D) 0.783, memory accuracy (4D)  0.52
# step 20000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.523
# step 21000, memory accuracy (2D) 0.773, memory accuracy (4D)  0.52
# step 22000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.517
# step 23000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.533
# step 24000, memory accuracy (2D) 0.773, memory accuracy (4D)  0.53
# step 25000, memory accuracy (2D) 0.777, memory accuracy (4D)  0.54
# step 26000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.523
# 23262
# step 00000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.577
# step 01000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.573
# step 02000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.583
# step 03000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.573
# step 04000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.58
# step 05000, memory accuracy (2D) 0.753, memory accuracy (4D)  0.59
# step 06000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.583
# step 07000, memory accuracy (2D) 0.753, memory accuracy (4D)  0.58
# step 08000, memory accuracy (2D) 0.763, memory accuracy (4D) 0.573
# step 09000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.583
# step 10000, memory accuracy (2D)  0.76, memory accuracy (4D)  0.58
# step 11000, memory accuracy (2D) 0.757, memory accuracy (4D) 0.577
# step 12000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.577
# step 13000, memory accuracy (2D)  0.77, memory accuracy (4D) 0.587
# step 14000, memory accuracy (2D) 0.763, memory accuracy (4D) 0.593
# step 15000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.587
# step 16000, memory accuracy (2D) 0.753, memory accuracy (4D)  0.59
# step 17000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.587
# step 18000, memory accuracy (2D)  0.75, memory accuracy (4D)  0.59
# step 19000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.587
# step 20000, memory accuracy (2D) 0.757, memory accuracy (4D) 0.597
# step 21000, memory accuracy (2D)  0.76, memory accuracy (4D) 0.587
# step 22000, memory accuracy (2D)  0.76, memory accuracy (4D)  0.59
# step 23000, memory accuracy (2D) 0.757, memory accuracy (4D)   0.6
# 22804
# step 00000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.567
# step 01000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.55
# step 02000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.55
# step 03000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.567
# step 04000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.57
# step 05000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.56
# step 06000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.56
# step 07000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.553
# step 08000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.557
# step 09000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.543
# step 10000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.54
# step 11000, memory accuracy (2D)  0.81, memory accuracy (4D)  0.54
# step 12000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.547
# step 13000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.547
# step 14000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.553
# step 15000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.56
# step 16000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.57
# step 17000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.56
# step 18000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.55
# step 19000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.55
# step 20000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.557
# step 21000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.567
# step 22000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.567
# 22035
# step 00000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.537
# step 01000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.543
# step 02000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.547
# step 03000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.553
# step 04000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.553
# step 05000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.557
# step 06000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.557
# step 07000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.573
# step 08000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.553
# step 09000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.567
# step 10000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.57
# step 11000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.563
# step 12000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.56
# step 13000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.563
# step 14000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.55
# step 15000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.557
# step 16000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.563
# step 17000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.563
# step 18000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.567
# step 19000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.573
# step 20000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.573
# step 21000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.57
# 17048
# step 00000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.537
# step 01000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.547
# step 02000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.527
# step 03000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.53
# step 04000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.537
# step 05000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.53
# step 06000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.527
# step 07000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.527
# step 08000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.523
# step 09000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.523
# step 10000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.527
# step 11000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.527
# step 12000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.527
# step 13000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.543
# step 14000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.55
# step 15000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.543
# step 16000, memory accuracy (2D)  0.78, memory accuracy (4D)  0.54
# 17353
# step 00000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.54
# step 01000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.547
# step 02000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.537
# step 03000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.54
# step 04000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.547
# step 05000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.543
# step 06000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.547
# step 07000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.55
# step 08000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.563
# step 09000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.553
# step 10000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.547
# step 11000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.543
# step 12000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.543
# step 13000, memory accuracy (2D) 0.823, memory accuracy (4D)  0.55
# step 14000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.56
# step 15000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.567
# step 16000, memory accuracy (2D) 0.837, memory accuracy (4D)  0.55
# step 17000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.547
# 20054
# step 00000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.557
# step 01000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.553
# step 02000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.557
# step 03000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.56
# step 04000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.55
# step 05000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.57
# step 06000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.567
# step 07000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.567
# step 08000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.57
# step 09000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.593
# step 10000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.59
# step 11000, memory accuracy (2D)  0.81, memory accuracy (4D)  0.58
# step 12000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.58
# step 13000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.577
# step 14000, memory accuracy (2D)  0.81, memory accuracy (4D)  0.59
# step 15000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.593
# step 16000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.597
# step 17000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.593
# step 18000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.59
# step 19000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.56
# 18172
# step 00000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.567
# step 01000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.577
# step 02000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.583
# step 03000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.577
# step 04000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.597
# step 05000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.59
# step 06000, memory accuracy (2D)   0.8, memory accuracy (4D)   0.6
# step 07000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.587
# step 08000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.597
# step 09000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.593
# step 10000, memory accuracy (2D) 0.813, memory accuracy (4D)   0.6
# step 11000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.603
# step 12000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.593
# step 13000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.597
# step 14000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.587
# step 15000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.583
# step 16000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.58
# step 17000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.58
# step 18000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.59
# 15082
# step 00000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.567
# step 01000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.567
# step 02000, memory accuracy (2D) 0.753, memory accuracy (4D) 0.557
# step 03000, memory accuracy (2D) 0.743, memory accuracy (4D)  0.55
# step 04000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.547
# step 05000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.56
# step 06000, memory accuracy (2D) 0.747, memory accuracy (4D)  0.56
# step 07000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.543
# step 08000, memory accuracy (2D) 0.747, memory accuracy (4D) 0.543
# step 09000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.543
# step 10000, memory accuracy (2D)  0.74, memory accuracy (4D)  0.54
# step 11000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.543
# step 12000, memory accuracy (2D) 0.737, memory accuracy (4D)  0.54
# step 13000, memory accuracy (2D) 0.737, memory accuracy (4D) 0.537
# step 14000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.547
# 16209
# step 00000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.64
# step 01000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.637
# step 02000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.637
# step 03000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.623
# step 04000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.623
# step 05000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.617
# step 06000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.627
# step 07000, memory accuracy (2D) 0.823, memory accuracy (4D)  0.63
# step 08000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.627
# step 09000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.633
# step 10000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.64
# step 11000, memory accuracy (2D) 0.827, memory accuracy (4D)  0.64
# step 12000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.627
# step 13000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.633
# step 14000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.623
# step 15000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.63
# step 16000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.637
# 17981
# step 00000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.573
# step 01000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.57
# step 02000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.57
# step 03000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.573
# step 04000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.56
# step 05000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.56
# step 06000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.56
# step 07000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.58
# step 08000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.573
# step 09000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.567
# step 10000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.577
# step 11000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.563
# step 12000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.58
# step 13000, memory accuracy (2D) 0.783, memory accuracy (4D)  0.58
# step 14000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.587
# step 15000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.593
# step 16000, memory accuracy (2D) 0.787, memory accuracy (4D)   0.6
# step 17000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.593
# 17829
# step 00000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.61
# step 01000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.617
# step 02000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.613
# step 03000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.64
# step 04000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.623
# step 05000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.617
# step 06000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.613
# step 07000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.617
# step 08000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.623
# step 09000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.62
# step 10000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.62
# step 11000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.61
# step 12000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.603
# step 13000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.617
# step 14000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.62
# step 15000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.62
# step 16000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.62
# step 17000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.627
# 20411
# step 00000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.647
# step 01000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.627
# step 02000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.63
# step 03000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.633
# step 04000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.643
# step 05000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.633
# step 06000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.647
# step 07000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.647
# step 08000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.64
# step 09000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.64
# step 10000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.643
# step 11000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.64
# step 12000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.64
# step 13000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.637
# step 14000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.63
# step 15000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.63
# step 16000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.637
# step 17000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.647
# step 18000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.64
# step 19000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.653
# step 20000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.657
# 22047
# step 00000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.627
# step 01000, memory accuracy (2D) 0.783, memory accuracy (4D)  0.63
# step 02000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.607
# step 03000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.61
# step 04000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.617
# step 05000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.607
# step 06000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.607
# step 07000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.613
# step 08000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.613
# step 09000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.61
# step 10000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.603
# step 11000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.597
# step 12000, memory accuracy (2D) 0.793, memory accuracy (4D)   0.6
# step 13000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.61
# step 14000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.613
# step 15000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.627
# step 16000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.623
# step 17000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.61
# step 18000, memory accuracy (2D)  0.78, memory accuracy (4D)  0.62
# step 19000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.603
# step 20000, memory accuracy (2D) 0.783, memory accuracy (4D)   0.6
# step 21000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.597
# 25484
# step 00000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.597
# step 01000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.593
# step 02000, memory accuracy (2D) 0.817, memory accuracy (4D)   0.6
# step 03000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.59
# step 04000, memory accuracy (2D)  0.81, memory accuracy (4D)   0.6
# step 05000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.597
# step 06000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.593
# step 07000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.597
# step 08000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.597
# step 09000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.597
# step 10000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.587
# step 11000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.587
# step 12000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.587
# step 13000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.583
# step 14000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.593
# step 15000, memory accuracy (2D) 0.817, memory accuracy (4D)   0.6
# step 16000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.607
# step 17000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.597
# step 18000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.603
# step 19000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.603
# step 20000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.607
# step 21000, memory accuracy (2D) 0.833, memory accuracy (4D)   0.6
# step 22000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.603
# step 23000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.597
# step 24000, memory accuracy (2D) 0.827, memory accuracy (4D)   0.6
# step 25000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.593
# 22161
# step 00000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.593
# step 01000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.593
# step 02000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.597
# step 03000, memory accuracy (2D) 0.783, memory accuracy (4D)  0.59
# step 04000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.587
# step 05000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.593
# step 06000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.59
# step 07000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.587
# step 08000, memory accuracy (2D) 0.787, memory accuracy (4D)   0.6
# step 09000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.593
# step 10000, memory accuracy (2D)  0.79, memory accuracy (4D)   0.6
# step 11000, memory accuracy (2D) 0.767, memory accuracy (4D) 0.587
# step 12000, memory accuracy (2D) 0.763, memory accuracy (4D) 0.587
# step 13000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.603
# step 14000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.603
# step 15000, memory accuracy (2D) 0.777, memory accuracy (4D)   0.6
# step 16000, memory accuracy (2D) 0.773, memory accuracy (4D)   0.6
# step 17000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.597
# step 18000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.593
# step 19000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.593
# step 20000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.597
# step 21000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.597
# step 22000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.593
# 20333
# step 00000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.607
# step 01000, memory accuracy (2D) 0.773, memory accuracy (4D) 0.593
# step 02000, memory accuracy (2D) 0.773, memory accuracy (4D)  0.59
# step 03000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.613
# step 04000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.603
# step 05000, memory accuracy (2D) 0.773, memory accuracy (4D)  0.59
# step 06000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.583
# step 07000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.603
# step 08000, memory accuracy (2D) 0.787, memory accuracy (4D)   0.6
# step 09000, memory accuracy (2D)  0.79, memory accuracy (4D)   0.6
# step 10000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.613
# step 11000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.627
# step 12000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.607
# step 13000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.603
# step 14000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.603
# step 15000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.59
# step 16000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.603
# step 17000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.59
# step 18000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.587
# step 19000, memory accuracy (2D) 0.793, memory accuracy (4D)   0.6
# step 20000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.607
# 18649
# step 00000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.647
# step 01000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.647
# step 02000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.65
# step 03000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.653
# step 04000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.65
# step 05000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.643
# step 06000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.643
# step 07000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.643
# step 08000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.64
# step 09000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.64
# step 10000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.64
# step 11000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.643
# step 12000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.65
# step 13000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.65
# step 14000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.647
# step 15000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.643
# step 16000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.64
# step 17000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.647
# step 18000, memory accuracy (2D) 0.783, memory accuracy (4D)  0.64
# 19152
# step 00000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.63
# step 01000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.63
# step 02000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.643
# step 03000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.633
# step 04000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.613
# step 05000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.623
# step 06000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.627
# step 07000, memory accuracy (2D) 0.847, memory accuracy (4D)  0.61
# step 08000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.627
# step 09000, memory accuracy (2D) 0.837, memory accuracy (4D)  0.62
# step 10000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.613
# step 11000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.613
# step 12000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.63
# step 13000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.623
# step 14000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.633
# step 15000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.623
# step 16000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.627
# step 17000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.62
# step 18000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.613
# step 19000, memory accuracy (2D) 0.843, memory accuracy (4D)  0.61
# 17045
# step 00000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.613
# step 01000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.623
# step 02000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.617
# step 03000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.613
# step 04000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.613
# step 05000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.607
# step 06000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.607
# step 07000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.607
# step 08000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.613
# step 09000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.61
# step 10000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.617
# step 11000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.613
# step 12000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.607
# step 13000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.603
# step 14000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.607
# step 15000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.613
# step 16000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.607
# 19556
# step 00000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.57
# step 01000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.57
# step 02000, memory accuracy (2D)  0.81, memory accuracy (4D)  0.57
# step 03000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.567
# step 04000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.593
# step 05000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.597
# step 06000, memory accuracy (2D) 0.813, memory accuracy (4D)  0.58
# step 07000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.577
# step 08000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.567
# step 09000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.573
# step 10000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.597
# step 11000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.59
# step 12000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.583
# step 13000, memory accuracy (2D)  0.81, memory accuracy (4D)  0.59
# step 14000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.597
# step 15000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.597
# step 16000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.587
# step 17000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.587
# step 18000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.58
# step 19000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.583
# 19560
# step 00000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.593
# step 01000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.593
# step 02000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.587
# step 03000, memory accuracy (2D) 0.783, memory accuracy (4D)  0.59
# step 04000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.583
# step 05000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.593
# step 06000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.593
# step 07000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.59
# step 08000, memory accuracy (2D) 0.787, memory accuracy (4D)   0.6
# step 09000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.59
# step 10000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.593
# step 11000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.597
# step 12000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.593
# step 13000, memory accuracy (2D)  0.78, memory accuracy (4D)   0.6
# step 14000, memory accuracy (2D) 0.787, memory accuracy (4D)  0.59
# step 15000, memory accuracy (2D) 0.787, memory accuracy (4D) 0.593
# step 16000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.597
# step 17000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.613
# step 18000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.61
# step 19000, memory accuracy (2D)  0.78, memory accuracy (4D) 0.587
# 20546
# step 00000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.667
# step 01000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.66
# step 02000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.657
# step 03000, memory accuracy (2D) 0.857, memory accuracy (4D) 0.657
# step 04000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.653
# step 05000, memory accuracy (2D) 0.843, memory accuracy (4D)  0.65
# step 06000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.653
# step 07000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.657
# step 08000, memory accuracy (2D)  0.86, memory accuracy (4D) 0.667
# step 09000, memory accuracy (2D) 0.853, memory accuracy (4D)  0.66
# step 10000, memory accuracy (2D)  0.86, memory accuracy (4D) 0.667
# step 11000, memory accuracy (2D) 0.863, memory accuracy (4D) 0.657
# step 12000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.64
# step 13000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.643
# step 14000, memory accuracy (2D)  0.86, memory accuracy (4D) 0.657
# step 15000, memory accuracy (2D) 0.857, memory accuracy (4D)  0.67
# step 16000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.647
# step 17000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.657
# step 18000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.667
# step 19000, memory accuracy (2D)  0.86, memory accuracy (4D) 0.677
# step 20000, memory accuracy (2D)  0.87, memory accuracy (4D)  0.67
# 20586
# step 00000, memory accuracy (2D)  0.86, memory accuracy (4D)  0.64
# step 01000, memory accuracy (2D)  0.81, memory accuracy (4D)  0.63
# step 02000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.62
# step 03000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.627
# step 04000, memory accuracy (2D)  0.85, memory accuracy (4D)  0.63
# step 05000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.633
# step 06000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.64
# step 07000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.633
# step 08000, memory accuracy (2D) 0.843, memory accuracy (4D)  0.64
# step 09000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.623
# step 10000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.617
# step 11000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.623
# step 12000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.62
# step 13000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.627
# step 14000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.623
# step 15000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.607
# step 16000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.623
# step 17000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.633
# step 18000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.62
# step 19000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.63
# step 20000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.647
# 22494
# step 00000, memory accuracy (2D) 0.797, memory accuracy (4D) 0.607
# step 01000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.613
# step 02000, memory accuracy (2D) 0.767, memory accuracy (4D)   0.6
# step 03000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.607
# step 04000, memory accuracy (2D)  0.75, memory accuracy (4D)  0.61
# step 05000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.603
# step 06000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.613
# step 07000, memory accuracy (2D) 0.727, memory accuracy (4D) 0.613
# step 08000, memory accuracy (2D) 0.743, memory accuracy (4D) 0.603
# step 09000, memory accuracy (2D)  0.74, memory accuracy (4D) 0.597
# step 10000, memory accuracy (2D) 0.723, memory accuracy (4D) 0.593
# step 11000, memory accuracy (2D) 0.743, memory accuracy (4D)  0.59
# step 12000, memory accuracy (2D)   0.7, memory accuracy (4D) 0.593
# step 13000, memory accuracy (2D)  0.73, memory accuracy (4D) 0.607
# step 14000, memory accuracy (2D)  0.75, memory accuracy (4D) 0.607
# step 15000, memory accuracy (2D) 0.747, memory accuracy (4D)   0.6
# step 16000, memory accuracy (2D)  0.76, memory accuracy (4D)   0.6
# ...
# step 05000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.69
# step 06000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.683
# step 07000, memory accuracy (2D) 0.823, memory accuracy (4D)  0.67
# step 08000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.69
# step 09000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.69
# step 10000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.693
# step 11000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.677
# step 12000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.677
# step 13000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.683
# step 14000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.69
# step 15000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.68
# step 16000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.67
# step 17000, memory accuracy (2D) 0.827, memory accuracy (4D)  0.67
# step 18000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.687
# step 19000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.69
# step 20000, memory accuracy (2D) 0.827, memory accuracy (4D)  0.67
# step 21000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.673
# step 22000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.667
# 26157
# step 00000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.613
# step 01000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.607
# step 02000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.613
# step 03000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.613
# step 04000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.603
# step 05000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.617
# step 06000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.613
# step 07000, memory accuracy (2D) 0.817, memory accuracy (4D)   0.6
# step 08000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.607
# step 09000, memory accuracy (2D) 0.823, memory accuracy (4D)   0.6
# step 10000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.603
# step 11000, memory accuracy (2D) 0.833, memory accuracy (4D)   0.6
# step 12000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.593
# step 13000, memory accuracy (2D) 0.823, memory accuracy (4D)   0.6
# step 14000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.593
# step 15000, memory accuracy (2D) 0.833, memory accuracy (4D)   0.6
# step 16000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.61
# step 17000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.613
# step 18000, memory accuracy (2D)  0.81, memory accuracy (4D)   0.6
# step 19000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.603
# step 20000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.61
# step 21000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.61
# step 22000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.597
# step 23000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.603
# step 24000, memory accuracy (2D) 0.823, memory accuracy (4D)  0.59
# step 25000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.593
# step 26000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.603
# 27642
# step 00000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.653
# step 01000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.653
# step 02000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.657
# step 03000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.657
# step 04000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.653
# step 05000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.653
# step 06000, memory accuracy (2D) 0.837, memory accuracy (4D)  0.65
# step 07000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.653
# step 08000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.65
# step 09000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.653
# step 10000, memory accuracy (2D)  0.86, memory accuracy (4D)  0.66
# step 11000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.667
# step 12000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.663
# step 13000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.67
# step 14000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.66
# step 15000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.667
# step 16000, memory accuracy (2D) 0.847, memory accuracy (4D)  0.67
# step 17000, memory accuracy (2D)  0.85, memory accuracy (4D)  0.67
# step 18000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.677
# step 19000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.663
# step 20000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.657
# step 21000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.663
# step 22000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.657
# step 23000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.653
# step 24000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.663
# step 25000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.667
# step 26000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.667
# step 27000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.663
# 24478
# step 00000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.613
# step 01000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.63
# step 02000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.63
# step 03000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.617
# step 04000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.623
# step 05000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.623
# step 06000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.623
# step 07000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.627
# step 08000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.627
# step 09000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.627
# step 10000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.633
# step 11000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.62
# step 12000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.617
# step 13000, memory accuracy (2D) 0.803, memory accuracy (4D)  0.62
# step 14000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.633
# step 15000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.633
# step 16000, memory accuracy (2D)   0.8, memory accuracy (4D) 0.623
# step 17000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.62
# step 18000, memory accuracy (2D) 0.793, memory accuracy (4D) 0.633
# step 19000, memory accuracy (2D)  0.79, memory accuracy (4D) 0.633
# step 20000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.627
# step 21000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.633
# step 22000, memory accuracy (2D)   0.8, memory accuracy (4D)  0.62
# step 23000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.627
# step 24000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.637
# 21229
# step 00000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.657
# step 01000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.64
# step 02000, memory accuracy (2D) 0.797, memory accuracy (4D)  0.65
# step 03000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.667
# step 04000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.66
# step 05000, memory accuracy (2D) 0.777, memory accuracy (4D) 0.643
# step 06000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.657
# step 07000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.657
# step 08000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.67
# step 09000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.67
# step 10000, memory accuracy (2D) 0.807, memory accuracy (4D) 0.657
# step 11000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.667
# step 12000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.657
# step 13000, memory accuracy (2D) 0.803, memory accuracy (4D) 0.657
# step 14000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.667
# step 15000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.67
# step 16000, memory accuracy (2D) 0.793, memory accuracy (4D)  0.66
# step 17000, memory accuracy (2D)  0.81, memory accuracy (4D) 0.673
# step 18000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.68
# step 19000, memory accuracy (2D) 0.807, memory accuracy (4D)  0.67
# step 20000, memory accuracy (2D) 0.783, memory accuracy (4D) 0.663
# step 21000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.677
# 17816
# step 00000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.707
# step 01000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.687
# step 02000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.693
# step 03000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.687
# step 04000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.697
# step 05000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.707
# step 06000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.707
# step 07000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.703
# step 08000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.697
# step 09000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.717
# step 10000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.717
# step 11000, memory accuracy (2D) 0.843, memory accuracy (4D)   0.7
# step 12000, memory accuracy (2D)  0.79, memory accuracy (4D)  0.66
# step 13000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.707
# step 14000, memory accuracy (2D)  0.85, memory accuracy (4D)  0.71
# step 15000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.703
# step 16000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.69
# step 17000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.693
# 15763
# step 00000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.667
# step 01000, memory accuracy (2D) 0.847, memory accuracy (4D)  0.66
# step 02000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.657
# step 03000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.657
# step 04000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.653
# step 05000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.65
# step 06000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.663
# step 07000, memory accuracy (2D) 0.843, memory accuracy (4D) 0.663
# step 08000, memory accuracy (2D) 0.857, memory accuracy (4D)  0.65
# step 09000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.647
# step 10000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.643
# step 11000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.643
# step 12000, memory accuracy (2D) 0.847, memory accuracy (4D)  0.64
# step 13000, memory accuracy (2D) 0.863, memory accuracy (4D) 0.653
# step 14000, memory accuracy (2D) 0.857, memory accuracy (4D)  0.66
# step 15000, memory accuracy (2D)  0.85, memory accuracy (4D) 0.657
# 13563
# step 00000, memory accuracy (2D) 0.857, memory accuracy (4D) 0.693
# step 01000, memory accuracy (2D) 0.867, memory accuracy (4D)  0.69
# step 02000, memory accuracy (2D) 0.863, memory accuracy (4D)  0.69
# step 03000, memory accuracy (2D)  0.87, memory accuracy (4D) 0.683
# step 04000, memory accuracy (2D) 0.863, memory accuracy (4D)  0.69
# step 05000, memory accuracy (2D) 0.847, memory accuracy (4D) 0.697
# step 06000, memory accuracy (2D) 0.853, memory accuracy (4D) 0.697
# step 07000, memory accuracy (2D)  0.89, memory accuracy (4D)  0.68
# step 08000, memory accuracy (2D) 0.887, memory accuracy (4D)  0.68
# step 09000, memory accuracy (2D) 0.863, memory accuracy (4D) 0.687
# step 10000, memory accuracy (2D) 0.847, memory accuracy (4D)  0.69
# step 11000, memory accuracy (2D) 0.873, memory accuracy (4D) 0.687
# step 12000, memory accuracy (2D) 0.873, memory accuracy (4D)  0.69
# step 13000, memory accuracy (2D)  0.89, memory accuracy (4D) 0.683
# 14802
# step 00000, memory accuracy (2D) 0.817, memory accuracy (4D)   0.6
# step 01000, memory accuracy (2D)  0.81, memory accuracy (4D)   0.6
# step 02000, memory accuracy (2D) 0.813, memory accuracy (4D) 0.603
# step 03000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.603
# step 04000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.607
# step 05000, memory accuracy (2D) 0.823, memory accuracy (4D)   0.6
# step 06000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.607
# step 07000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.597
# step 08000, memory accuracy (2D)  0.81, memory accuracy (4D)   0.6
# step 09000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.603
# step 10000, memory accuracy (2D)  0.82, memory accuracy (4D)   0.6
# step 11000, memory accuracy (2D) 0.827, memory accuracy (4D)   0.6
# step 12000, memory accuracy (2D) 0.823, memory accuracy (4D)  0.61
# step 13000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.603
# step 14000, memory accuracy (2D) 0.823, memory accuracy (4D)   0.6
# 16040
# step 00000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.617
# step 01000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.627
# step 02000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.63
# step 03000, memory accuracy (2D) 0.837, memory accuracy (4D)  0.64
# step 04000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.647
# step 05000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.623
# step 06000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.627
# step 07000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.647
# step 08000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.627
# step 09000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.627
# step 10000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.637
# step 11000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.64
# step 12000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.633
# step 13000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.633
# step 14000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.637
# step 15000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.637
# 18864
# step 00000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.66
# step 01000, memory accuracy (2D) 0.823, memory accuracy (4D) 0.673
# step 02000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.667
# step 03000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.657
# step 04000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.663
# step 05000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.663
# step 06000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.657
# step 07000, memory accuracy (2D)  0.82, memory accuracy (4D)  0.65
# step 08000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.653
# step 09000, memory accuracy (2D) 0.823, memory accuracy (4D)  0.65
# step 10000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.653
# step 11000, memory accuracy (2D) 0.817, memory accuracy (4D)  0.65
# step 12000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.647
# step 13000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.657
# step 14000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.653
# step 15000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.653
# step 16000, memory accuracy (2D) 0.817, memory accuracy (4D) 0.657
# step 17000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.653
# step 18000, memory accuracy (2D)  0.82, memory accuracy (4D) 0.643
# 18490
# step 00000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.647
# step 01000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.647
# step 02000, memory accuracy (2D)  0.84, memory accuracy (4D)  0.65
# step 03000, memory accuracy (2D) 0.837, memory accuracy (4D)  0.65
# step 04000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.637
# step 05000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.633
# step 06000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.64
# step 07000, memory accuracy (2D) 0.837, memory accuracy (4D)  0.64
# step 08000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.637
# step 09000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.647
# step 10000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.647
# step 11000, memory accuracy (2D) 0.833, memory accuracy (4D) 0.653
# step 12000, memory accuracy (2D) 0.833, memory accuracy (4D)  0.65
# step 13000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.657
# step 14000, memory accuracy (2D) 0.827, memory accuracy (4D) 0.657
# step 15000, memory accuracy (2D)  0.83, memory accuracy (4D) 0.657
# step 16000, memory accuracy (2D) 0.837, memory accuracy (4D) 0.657
# step 17000, memory accuracy (2D)  0.83, memory accuracy (4D)  0.66
# step 18000, memory accuracy (2D)  0.84, memory accuracy (4D) 0.657

# %%
save_path = saver.save(sess, "D:/OSU/results/save/2.7/",global_step=n)

# %%
############################## Save the output of new maps ##############################

dataList=os.listdir('C:/OSU/SongMat/Create/')
# inputOsuNew=np.empty([0,128*128]);
for i in range(np.size(dataList)):
    if not dataList[i][0]=='y':
        data=sio.loadmat('C:/OSU/SongMat/Create/'+dataList[i])
        print(data['osuFolder'])
        
        inputOsuNew=data['input'].reshape(-1,128*128)
        outputOsuNew=data['target']
        outputOsu2New=np.zeros([outputOsuNew.shape[0],2]);
        outputOsu2New[:,0]=outputOsuNew[:,0]+outputOsuNew[:,1]+outputOsuNew[:,2]
        outputOsu2New[:,1]=outputOsuNew[:,3]
        
        y_result_2 = np.empty([0,2])
        y_result_4 = np.empty([0,4])
        step_size = 100
        cursor = 0
        
        print ("test accuracy %g"%accuracy_2.eval(feed_dict={x: inputOsuNew[-300:,:], y_2: outputOsu2New[-300:,:], keep_prob: 1.0}))
        while cursor < inputOsuNew.shape[0]:
            if inputOsuNew[cursor:,:].shape[0] > step_size:
                y_result_2_1 = y2.eval(feed_dict={x: inputOsuNew[cursor:(cursor+step_size):1,:], keep_prob: 1.0})
                y_result_4_1 = y4.eval(feed_dict={x: inputOsuNew[cursor:(cursor+step_size):1,:], keep_prob: 1.0})
                y_result_2 = np.append(y_result_2,y_result_2_1,axis=0)
                y_result_4 = np.append(y_result_4,y_result_4_1,axis=0)
            else:
                y_result_2_1 = y2.eval(feed_dict={x: inputOsuNew[cursor:(cursor+step_size):1,:], keep_prob: 1.0})
                y_result_4_1 = y4.eval(feed_dict={x: inputOsuNew[cursor:(cursor+step_size):1,:], keep_prob: 1.0})
                y_result_2 = np.append(y_result_2,y_result_2_1,axis=0)
                y_result_4 = np.append(y_result_4,y_result_4_1,axis=0)
            cursor+=step_size
            
        data_save={'y2':y_result_2, 'y4':y_result_4}

        sio.savemat('C:/OSU/SongMat/Create/y_'+dataList[i],data_save)
